# %%
# !nvidia-smi
# Out:
# Sun Apr 19 10:52:41 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.64.00    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   63C    P8    10W /  70W |      0MiB / 15079MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# ...

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd '/gdrive/My Drive/SRU_Project/CycleGAN'
# %cd Pytorch-CycleGAN-VC2/
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive
# /gdrive/My Drive/SRU_Project/CycleGAN
# /gdrive/My Drive/SRU_Project/CycleGAN/Pytorch-CycleGAN-VC2

# %%
# !pip install pyworld
# Out:
# ...
#      |████████████████████████████████| 81kB 996kB/s
# ...
#   Created wheel for pyworld: filename=pyworld-0.2.8-cp36-cp36m-linux_x86_64.whl size=618543 sha256=d8a2c66497843bd6baa8866f130d43e15e2ff526b792b144cf6511e44275fbde
#   Stored in directory: /root/.cache/pip/wheels/c3/58/e5/a7e39ab92c56825f976970b97066753c68406c7fb0d80d4a4a
# Successfully built pyworld
# ...

# %%
# sm1 to tf1
# !python train2.py
# # sf1 to tf2
# !python train.py
# Out:
# Training resumed
# Epoch: 441 Generator Loss: 7.4059 Discriminator Loss: 2.5810250008362345e-06, Time: 79.78
#
#
# Iter:8850	 Generator Loss:7.8562 Discrimator Loss:0.0000 	GA2B:0.9974 GB2A:0.9987 G_id:0.3710 G_cyc:0.4005 D_A:0.0000 D_B:0.0000
# Epoch: 442 Generator Loss: 7.2307 Discriminator Loss: 3.994944563601166e-06, Time: 79.61
#
#
# Epoch: 443 Generator Loss: 7.6090 Discriminator Loss: 1.1019748853868805e-05, Time: 79.57
#
#
# Iter:8900	 Generator Loss:7.0932 Discrimator Loss:0.0000 	GA2B:0.9964 GB2A:0.9987 G_id:0.3148 G_cyc:0.3524 D_A:0.0000 D_B:0.0000
# Epoch: 444 Generator Loss: 7.0932 Discriminator Loss: 3.793364157900214e-06, Time: 79.67
#
#
# Iter:8900	 Generator Loss:8.1501 Discrimator Loss:0.0000 	GA2B:0.9971 GB2A:0.9993 G_id:0.3672 G_cyc:0.4318 D_A:0.0000 D_B:0.0000
# Epoch: 445 Generator Loss: 7.9720 Discriminator Loss: 4.491674644668819e-06, Time: 79.69
#
#
# Epoch: 446 Generator Loss: 7.6841 Discriminator Loss: 8.96239157555101e-07, Time: 79.61
#
#
# ...

# %%
# !python preprocess_training.py --train_A_dir ./data/vcc2016_training/SM1 --train_B_dir ./data/vcc2016_training/TF1 --cache_folder ./cache/sm1_tf1/
# Out:
# Starting to prepocess data.......
# Log Pitch A
# Mean: 4.6134, Std: 0.1743
# Log Pitch B
# Mean: 5.4552, Std: 0.2325
# Preprocessing finsihed!! see your directory ../cache for cached preprocessed data
# Time taken for preprocessing 675.8077 seconds
