# %%
# !nvidia-smi
# Out:
# Tue Apr 28 04:44:10 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.64.00    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# ...

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd '/gdrive/My Drive/SRU_Project/CycleGAN'
# %cd Pytorch-CycleGAN-VC2/
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive
# /gdrive/My Drive/SRU_Project/CycleGAN
# /gdrive/My Drive/SRU_Project/CycleGAN/Pytorch-CycleGAN-VC2

# %%
# !pip install pyworld
# Out:
# ...
#      |████████████████████████████████| 81kB 2.1MB/s
# ...
#   Created wheel for pyworld: filename=pyworld-0.2.8-cp36-cp36m-linux_x86_64.whl size=619294 sha256=36024072767ae6482692fe26d17569ccfda38b85504ecbb290db7cb5f44ca94a
#   Stored in directory: /root/.cache/pip/wheels/c3/58/e5/a7e39ab92c56825f976970b97066753c68406c7fb0d80d4a4a
# Successfully built pyworld
# ...

# %%
# !python preprocess_training.py --train_A_dir ./data/cmu_train/cmu_in_250 --train_B_dir ./data/cmu_train/cmu_us_250 --cache_folder ./cache/cmu

# %%
# !python test.py --logf0s_normalization ./cache/malayalam/logf0s_normalization.npz --mcep_normalization ./cache/malayalam/mcep_normalization.npz --test_A_dir ./data/malayalam_train/female_9 --output_A_dir ./data/malayalam_train/converted_sound/ml17 --model_checkpoint ./cache/malayalam/model_checkpoint/_CycleGAN_CheckPoint

# %%
# !python cmu.py
# Out:
# Training resumed
# Iter:15400	 Generator Loss:3.9047 Discrimator Loss:0.0000 	GA2B:0.9994 GB2A:0.9970 G_id:0.7183 G_cyc:0.1908 D_A:0.0000 D_B:0.0000
# Epoch: 1026 Generator Loss: 3.9577 Discriminator Loss: 1.6362320820917375e-05, Time: 65.83
#
#
# Epoch: 1027 Generator Loss: 3.9680 Discriminator Loss: 5.601435077551287e-06, Time: 64.67
#
#
# Epoch: 1028 Generator Loss: 3.8540 Discriminator Loss: 1.3891448361391667e-05, Time: 64.64
#
#
# Iter:15450	 Generator Loss:3.9088 Discrimator Loss:0.0000 	GA2B:0.9993 GB2A:0.9976 G_id:0.7180 G_cyc:0.1912 D_A:0.0000 D_B:0.0000
# Epoch: 1029 Generator Loss: 3.9088 Discriminator Loss: 1.0130441296496429e-05, Time: 64.68
#
#
# Iter:15450	 Generator Loss:3.9821 Discrimator Loss:0.0000 	GA2B:0.9990 GB2A:0.9984 G_id:0.7115 G_cyc:0.1985 D_A:0.0000 D_B:0.0000
# Epoch: 1030 Generator Loss: 3.9064 Discriminator Loss: 2.2508869733428583e-05, Time: 64.71
#
#
# Epoch: 1031 Generator Loss: 4.0481 Discriminator Loss: 9.825362212723121e-06, Time: 64.61
#
#
# ...

# %%
# !python preprocess_training.py --train_A_dir ./data/vcc2016_training/SF1 --train_B_dir ./data/vcc2016_training/TF2 --cache_folder ./cache/sf1s_tf2
