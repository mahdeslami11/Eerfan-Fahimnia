# %%
# !nvidia-smi
# Out:
# Thu Apr 16 06:29:20 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.64.00    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P0    29W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# ...

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd '/gdrive/My Drive/SRU_Project/CycleGAN'
# %cd Pytorch-CycleGAN-VC2/
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive
# /gdrive/My Drive/SRU_Project/CycleGAN
# /gdrive/My Drive/SRU_Project/CycleGAN/Pytorch-CycleGAN-VC2

# %%
# !pip install pyworld
# Out:
# ...
#      |████████████████████████████████| 81kB 2.6MB/s
# ...
#   Created wheel for pyworld: filename=pyworld-0.2.8-cp36-cp36m-linux_x86_64.whl size=618553 sha256=960968354331c14258481f901c98fa17bbf99b43134bb39c930de9393c42eb8c
#   Stored in directory: /root/.cache/pip/wheels/c3/58/e5/a7e39ab92c56825f976970b97066753c68406c7fb0d80d4a4a
# Successfully built pyworld
# ...

# %%
#sf1 to tm1
# !python train2.py
# Out:
# Iter:0	 Generator Loss:26.6141 Discrimator Loss:0.2565 	GA2B:0.2518 GB2A:0.2570 G_id:1.7394 G_cyc:1.7408 D_A:0.2575 D_B:0.2555
# Epoch: 0 Generator Loss: 25.3415 Discriminator Loss: 0.09878581017255783, Time: 47.70
#
#
# Epoch: 1 Generator Loss: 22.3153 Discriminator Loss: 0.1322740912437439, Time: 47.69
#
#
# Iter:50	 Generator Loss:22.2969 Discrimator Loss:0.0343 	GA2B:0.8698 GB2A:0.8288 G_id:1.3067 G_cyc:1.4065 D_A:0.0385 D_B:0.0302
# Epoch: 2 Generator Loss: 22.6706 Discriminator Loss: 0.02403321862220764, Time: 47.73
#
#
# Epoch: 3 Generator Loss: 21.1407 Discriminator Loss: 0.00489771505817771, Time: 47.65
#
#
# Iter:100	 Generator Loss:20.1793 Discrimator Loss:0.0058 	GA2B:0.9499 GB2A:0.9072 G_id:1.1432 G_cyc:1.2606 D_A:0.0095 D_B:0.0020
# Epoch: 4 Generator Loss: 20.1793 Discriminator Loss: 0.005758034996688366, Time: 47.69
#
#
# Iter:100	 Generator Loss:21.7790 Discrimator Loss:0.0033 	GA2B:0.9440 GB2A:0.9436 G_id:1.1821 G_cyc:1.3981 D_A:0.0052 D_B:0.0015
# ...

# %%
# !ls t*.py
